# %%
import pandas as pd

df = pd.read_csv("../data/Library_Usage.csv")
df['Circulation Active Year']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#            ...
# 437110    2004.0
# 437111    2004.0
# 437112    2004.0
# 437113    2004.0
# 437114    2004.0
# Name: Circulation Active Year, Length: 437115, dtype: float64

# %%
2019 - df['Circulation Active Year']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 437110    15.0
# 437111    15.0
# 437112    15.0
# 437113    15.0
# 437114    15.0
# Name: Circulation Active Year, Length: 437115, dtype: float64

# %%
df.isna().sum()
# Out:
# Patron Type Code                    0
# Patron Type Definition              0
# Total Checkouts                     0
# Total Renewals                      0
# Age Range                         927
# Home Library Code                   2
# Home Library Definition             0
# Circulation Active Month        40592
# Circulation Active Year         40592
# Notice Preference Code              0
# Notice Preference Definition        0
# Provided Email Address              0
# Year Patron Registered              0
# Within San Francisco County         0
# dtype: int64

# %%
df[df['Age Range'].isna()]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 349                    0                  Adult                0
# 634                    3                 Senior                0
# 801                    0                  Adult                0
# 926                   15           Teacher Card                0
# 949                   15           Teacher Card                0
# ...                  ...                    ...              ...
# 429549                 5                  Staff               32
# 430618                55          Retired Staff              914
# 432900                 0                  Adult              837
# 436533                 5                  Staff              102
# 436599                 5                  Staff               25
#
#         Total Renewals Age Range Home Library Code Home Library Definition  \
# 349                  0       NaN                 x                    Main
# 634                  0       NaN               ylw              Bookmobile
# 801                  0       NaN                 x                    Main
# 926                  0       NaN                 x                    Main
# 949                  0       NaN                 x                    Main
# ...                ...       ...               ...                     ...
# 429549               9       NaN                 x                    Main
# 430618             393       NaN                 x                    Main
# 432900             262       NaN                r3                Richmond
# 436533              55       NaN                yb              Bookmobile
# 436599               0       NaN                 x                    Main
#
#        Circulation Active Month  Circulation Active Year  \
# 349                         NaN                      NaN
# 634                         NaN                      NaN
# 801                         NaN                      NaN
# 926                         NaN                      NaN
# 949                         NaN                      NaN
# ...                         ...                      ...
# 429549                 December                   2018.0
# 430618                     July                   2018.0
# 432900                     July                   2017.0
# 436533                  October                   2012.0
# 436599                     June                   2012.0
#
#        Notice Preference Code Notice Preference Definition  \
# 349                         z                        Email
# 634                         p                        Phone
# 801                         a                        Print
# 926                         z                        Email
# 949                         z                        Email
# ...                       ...                          ...
# 429549                      z                        Email
# 430618                      z                        Email
# 432900                      z                        Email
# 436533                      z                        Email
# 436599                      z                        Email
#
#         Provided Email Address  Year Patron Registered  \
# 349                       True                    2019
# 634                      False                    2019
# 801                      False                    2019
# 926                       True                    2020
# 949                       True                    2020
# ...                        ...                     ...
# 429549                    True                    2003
# 430618                    True                    2003
# 432900                    True                    2003
# 436533                    True                    2007
# 436599                    True                    2008
#
#         Within San Francisco County
# 349                            True
# 634                            True
# 801                            True
# 926                            True
# 949                            True
# ...                             ...
# 429549                         True
# 430618                         True
# 432900                         True
# 436533                         True
# 436599                         True
#
# [927 rows x 14 columns]

# %%
df[df['Age Range'].notna()]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      1               Juvenile                0
# 1                      2                   Teen                0
# 2                      0                  Adult                0
# 3                      2                   Teen                0
# 4                      2                   Teen                0
# ...                  ...                    ...              ...
# 437110                 0                  Adult               14
# 437111                 0                  Adult                2
# 437112                 3                 Senior                5
# 437113                 3                 Senior                4
# 437114                 3                 Senior                3
#
#         Total Renewals          Age Range Home Library Code  \
# 0                    0       0 to 9 years                r3
# 1                    0     10 to 19 years                 x
# 2                    0     35 to 44 years                m4
# 3                    0     10 to 19 years                 x
# 4                    0     10 to 19 years                b2
# ...                ...                ...               ...
# 437110              11     45 to 54 years                 x
# 437111               0     45 to 54 years                 x
# 437112               0  75 years and over                e7
# 437113               0     65 to 74 years                m6
# 437114               9     65 to 74 years                p9
#
#        Home Library Definition Circulation Active Month  \
# 0                     Richmond                      NaN
# 1                         Main                      NaN
# 2                       Merced                      NaN
# 3                         Main                      NaN
# 4                      Bayview                      NaN
# ...                        ...                      ...
# 437110                    Main                   August
# 437111                    Main                   August
# 437112           Eureka Valley                   August
# 437113                 Mission                   August
# 437114                Presidio                   August
#
#         Circulation Active Year Notice Preference Code  \
# 0                           NaN                      z
# 1                           NaN                      z
# 2                           NaN                      z
# 3                           NaN                      z
# 4                           NaN                      z
# ...                         ...                    ...
# 437110                   2004.0                      z
# 437111                   2004.0                      z
# 437112                   2004.0                      p
# 437113                   2004.0                      z
# 437114                   2004.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 0                             Email                    True
# 1                             Email                    True
# 2                             Email                    True
# 3                             Email                    True
# 4                             Email                    True
# ...                             ...                     ...
# 437110                        Email                    True
# 437111                        Email                    True
# 437112                        Phone                   False
# 437113                        Email                    True
# 437114                        Email                    True
#
#         Year Patron Registered  Within San Francisco County
# 0                         2022                         True
# 1                         2022                         True
# 2                         2019                         True
# 3                         2021                         True
# 4                         2013                         True
# ...                        ...                          ...
# 437110                    2003                        False
# 437111                    2003                         True
# 437112                    2003                         True
# 437113                    2004                         True
# 437114                    2004                         True
#
# [436188 rows x 14 columns]

# %%
df['Circulation Active Year'] = pd.to_numeric(df['Circulation Active Year'], errors='coerce')

# %%
df['Circulation Active Year']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#            ...
# 437110    2004.0
# 437111    2004.0
# 437112    2004.0
# 437113    2004.0
# 437114    2004.0
# Name: Circulation Active Year, Length: 437115, dtype: float64

# %%
import numpy as np

np.int_(df['Circulation Active Year'])
# Out:
# array([-9223372036854775808, -9223372036854775808, -9223372036854775808,
#        ...,                 2004,                 2004,
#                        2004])
