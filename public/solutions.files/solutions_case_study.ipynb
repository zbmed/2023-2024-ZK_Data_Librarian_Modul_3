# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set()

df = pd.read_csv("../data/Library_Usage_Clean.csv")
sns.distplot(df['Total Checkouts'], kde=False)

# %%
df['Circulation Active Year'].max()
# Out:
# 2016.0

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District',
#        'Membership Duration'],
#       dtype='object')

# %%
df['Total Checkouts'].quantile(0.95)
# Out:
# 8965

# %%
df_filtered = df[df['Total Checkouts'] < 800]
sns.distplot(df_filtered['Total Checkouts'], kde=False)

# %%
df['Total Checkouts Sqrt'] = df['Total Checkouts']**0.5
sns.distplot(df['Total Checkouts Sqrt'], kde=False)

# %%
import numpy as np
df['Checkouts Per Month'] = df['Total Checkouts']/df['Membership Duration']
df['Checkouts Per Month'].replace(np.inf, np.nan, inplace=True)
df['Checkouts Per Month'].fillna(0, inplace=True)

# %%
sns.distplot(df['Checkouts Per Month']**0.5, kde=False)
